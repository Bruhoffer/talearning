# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score

# %%
TICKER = 'SPY'
INTERVAL = '1d'
PERIOD = '730d' if INTERVAL == '1h' else 'max'
SHIFT_RANGE = range(1, 120)
MACD_FAST = 12
MACD_SLOW = 27
MACD_SPAN = 9
MFI_LENGTH = 14
MFI_OVERBOUGHT = 70
MFI_OVERSOLD = 30
RSI_LENGTH = 14
RSI_OVERBOUGHT = 70
RSI_OVERSOLD = 30
BB_LEN = 20
DEVS = 2
CUTOFF = .5

LOOKBACK = 10000

STRATEGY = ['Volume_change', 'Close_change', 'High_change', 'Low_change', 'Open_change', 'BB', 'MACD_hist', 'RSI', 'MFI']
OPTIMAL_SHIFT = None

def get_data(ticker=TICKER, lookback=LOOKBACK, interval=INTERVAL):
    df = yf.download(ticker, interval=interval, auto_adjust=True, period=PERIOD)
    df.columns = df.columns.get_level_values(0)
    df = df.reset_index(drop=True)

    for c in df.columns:
        df[f'{c}_change'] = df[c].pct_change() * 100

    # only return the subset of data you are interested in
    subset = df.iloc[-lookback:, :]
    plt.figure()
    plt.plot(subset['Close'])
    plt.title(f'Price Movements for {ticker} During Study')

    return subset.dropna()

def add_BB(df, devs=DEVS, bb_len=BB_LEN):

    # can change to ema (use MACD video/code for reference)
    df['BB_SMA'] = df['Close'].rolling(bb_len).mean()

    # get the standard deviation of the close prices for the period
    df['BB_STD'] = df['Close'].rolling(bb_len).std()

    df['Upper_Band'] = df['BB_SMA'] + (devs * df['BB_STD'])
    df['Lower_Band'] = df['BB_SMA'] - (devs * df['BB_STD'])

    df['BB'] = (df['Upper_Band'] - df['Close']) / (df['Upper_Band'] - df['Lower_Band'])

    df = df.dropna()

    plt.figure()
    plt.plot(df['Close'], color='blue')
    plt.plot(df['Upper_Band'], color='orange')
    plt.plot(df['Lower_Band'], color='orange')
    plt.title(f'{TICKER} Bollinger Bands. Len: {BB_LEN}, Deviations: {DEVS}');

    return df

def add_RSI(df, length=RSI_LENGTH, overbought=RSI_OVERBOUGHT, oversold=RSI_OVERSOLD):

    price_change = df['Close'].diff()
    
    # separate gains/losses
    gain = price_change.where(price_change > 0, 0)
    loss = -price_change.where(price_change < 0, 0)

    # average gain vs loss
    avg_gain = gain.rolling(window=length).mean()
    avg_loss = loss.rolling(window=length).mean()

    # calculate rsi
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    df['RSI'] = rsi

    # plot the relative strength index
    plt.figure()
    plt.plot(df['RSI'])
    plt.axhline(overbought, color='red')
    plt.axhline(oversold, color='green')
    plt.title('Relative Strength Index')

    return df.dropna()

def add_MACD(df, fast=MACD_FAST, slow=MACD_SLOW, span=MACD_SPAN):

    df[f'{fast}_ema'] = df['Close'].ewm(span=fast).mean()
    df[f'{slow}_ema'] = df['Close'].ewm(span=slow).mean()

    # macd line is the difference betweent he fast and slow
    df[f'MACD'] = df[f'{fast}_ema'] - df[f'{slow}_ema']

    # macd signal is a 9-period moving average of this line
    df['Signal'] = df['MACD'].ewm(span=span).mean()

    # MACD histogram is almost always what is used in TA
    df['MACD_hist'] = df['MACD'] - df['Signal']

    # plot the histogram
    plt.figure()
    plt.bar(x=range(len(df)), height=df['MACD_hist'])
    plt.title(f'{MACD_FAST} - {MACD_SLOW} - {MACD_SPAN} MACD Histogram')

    return df

def add_MFI(df, length=MFI_LENGTH, overbought=MFI_OVERBOUGHT, oversold=MFI_OVERSOLD):
    df = df.copy()

    # Step 1: Calculate typical price
    df['Typical_Price'] = (df['High'] + df['Low'] + df['Close']) / 3

    # Step 2: Calculate raw money flow
    df['Raw_Money_Flow'] = df['Typical_Price'] * df['Volume']

    # Step 3: Classify positive/negative money flow
    df['Price_Change'] = df['Typical_Price'].diff()

    df['Pos_Flow'] = np.where(df['Price_Change'] > 0, df['Raw_Money_Flow'], 0)
    df['Neg_Flow'] = np.where(df['Price_Change'] < 0, df['Raw_Money_Flow'], 0)

    # Step 4: Money Flow Ratio and MFI
    pos_sum = df['Pos_Flow'].rolling(window=length).sum()
    neg_sum = df['Neg_Flow'].rolling(window=length).sum()
    mfr = pos_sum / neg_sum
    df['MFI'] = 100 - (100 / (1 + mfr))

    # Step 5: Plot
    plt.figure()
    plt.plot(df['MFI'], label='MFI')
    plt.axhline(overbought, color='red', linestyle='--', label='Overbought')
    plt.axhline(oversold, color='green', linestyle='--', label='Oversold')
    plt.title('Money Flow Index')
    plt.legend()
    plt.show()

    return df.dropna()

def add_target(df, shift):
    df = df.copy()
    df[f'Close + {shift}'] = df['Close'].shift(-shift)
    df['Target'] = (df[f'Close + {shift}'] > df['Close']).astype(int)
    return df.dropna().reset_index(drop=True)

def generate_regression_output(df, features=STRATEGY, target='Target', cutoff=CUTOFF):
    subset = df[features + [target]].replace([np.inf, -np.inf], np.nan).dropna()

    if len(subset) < 10:
        raise ValueError("Too few rows after cleaning.")

    # Shuffle to break temporal autocorrelation
    subset = subset.sample(frac=1).reset_index(drop=True)

    X = sm.add_constant(subset[features])
    y = subset[target]

    model = sm.Logit(y, X).fit(disp=0)
    y_pred_prob = model.predict(X)

    df = df.loc[subset.index]
    df['Prediction'] = (y_pred_prob > cutoff).astype(int)
    return df, y, y_pred_prob

def add_confusion_matrix(df):
    cm = confusion_matrix(df['Target'], df['Prediction'])
    labels = ['Down (0)', 'Up (1)']
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure()
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='.0f')
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

def add_roc_plot(y_true, y_scores, title="ROC Curve"):
    fpr, tpr, _ = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_prediction_distribution(y_pred_prob):
    plt.figure()
    plt.hist(y_pred_prob, bins=50, color='gray')
    plt.title('Distribution of Logistic Predictions')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

def explore_shift_auc(df_raw):
    print(f"Exploring AUC over SHIFT range for {TICKER} on {INTERVAL} interval\n")
    results = []

    for shift in SHIFT_RANGE:
        try:
            df = add_target(df_raw.copy(), shift)
            df, y, y_pred_prob = generate_regression_output(df)
            auc_score = roc_auc_score(y, y_pred_prob)
            print(f"Shift: {shift:2d} | AUC: {auc_score:.4f}")
            results.append({'Shift': shift, 'AUC': auc_score})
        except Exception as e:
            print(f"Shift {shift}: Skipped due to error ({e})")

    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values(by='AUC', ascending=False).reset_index(drop=True)
    return results_df

def main():
    global OPTIMAL_SHIFT

    # Load and preprocess data once
    df = get_data()
    df = add_MACD(df)
    df = add_MFI(df)
    df = add_BB(df)
    df = add_RSI(df)

    # Explore AUC over multiple shifts
    results_df = explore_shift_auc(df)
    plot_df = results_df.sort_values(by='Shift') 

    # Plot AUC vs. Shift
    plt.figure(figsize=(10, 5))
    plt.plot(plot_df['Shift'], plot_df['AUC'], marker='o')
    plt.title(f'AUC by SHIFT for {TICKER} ({INTERVAL})')
    plt.xlabel('SHIFT')
    plt.ylabel('AUC Score')
    plt.grid(True)
    plt.show()

    # Set optimal shift globally for future studies
    OPTIMAL_SHIFT = int(results_df.iloc[0]['Shift'])
    print(f"\n Optimal SHIFT based on AUC: {OPTIMAL_SHIFT}")

    # Final study with optimal shift
    print(f"\n🔍 Running final model analysis with SHIFT = {OPTIMAL_SHIFT}")
    df_final = add_target(df.copy(), shift=OPTIMAL_SHIFT)
    df_final, y_final, y_pred_prob = generate_regression_output(df_final)

    plot_prediction_distribution(y_pred_prob)
    add_roc_plot(y_final, y_pred_prob, title=f'ROC Curve (SHIFT = {OPTIMAL_SHIFT})')
    add_confusion_matrix(df_final)

    return df, results_df

    

# Run
df, results_df = main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Exploring AUC over SHIFT range for SPY on 1d interval
#
# Shift 1: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 2: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 3: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 4: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 5: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 6: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 7: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 8: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 9: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 10: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 11: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 12: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 13: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 14: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 15: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 16: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 17: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 18: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 19: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 20: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 21: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 22: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 23: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 24: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 25: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 26: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 27: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 28: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 29: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 30: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 31: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 32: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 33: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 34: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 35: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 36: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 37: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 38: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 39: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 40: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 41: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 42: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 43: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 44: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 45: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 46: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 47: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 48: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 49: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 50: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 51: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 52: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 53: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 54: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 55: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 56: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 57: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 58: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 59: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 60: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 61: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 62: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 63: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 64: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 65: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 66: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 67: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 68: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 69: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 70: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 71: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 72: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 73: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 74: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 75: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 76: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 77: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 78: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 79: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 80: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 81: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 82: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 83: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 84: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 85: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 86: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 87: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 88: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 89: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 90: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 91: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 92: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 93: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 94: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 95: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 96: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 97: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 98: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 99: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 100: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 101: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 102: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 103: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 104: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 105: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 106: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 107: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 108: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 109: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 110: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 111: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 112: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 113: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 114: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 115: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 116: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 117: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 118: Skipped due to error (name 'roc_auc_score' is not defined)
# Shift 119: Skipped due to error (name 'roc_auc_score' is not defined)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/yl/gn9fldpj69169vhn466y4klh0000gn/T/ipykernel_47148/3407422124.py in ?()
#     256
#     257
#     258
#     259 # Run
# --> 260 df, results_df = main()
#
# /var/folders/yl/gn9fldpj69169vhn466y4klh0000gn/T/ipykernel_47148/3407422124.py in ?()
#     226     df = add_BB(df)
#     227     df = add_RSI(df)
#     228
#     229     # Explore AUC over multiple shifts
# --> 230     results_df = explore_shift_auc(df)
#     231     plot_df = results_df.sort_values(by='Shift')
#     232
#     233     # Plot AUC vs. Shift
#
# /var/folders/yl/gn9fldpj69169vhn466y4klh0000gn/T/ipykernel_47148/3407422124.py in ?(df_raw)
#     212         except Exception as e:
#     213             print(f"Shift {shift}: Skipped due to error ({e})")
#     214
#     215     results_df = pd.DataFrame(results)
# --> 216     results_df = results_df.sort_values(by='AUC', ascending=False).reset_index(drop=True)
#     217     return results_df
#
# ~/Documents/backtest/myenv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# ~/Documents/backtest/myenv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'AUC'
